# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# OPTIONAL (more relevant for individual words)
from nltk.stem import LancasterStemmer, WordNetLemmatizer 
from nltk.corpus import stopwords
from nltk.probability import FreqDist
import re   # regex
import unicodedata
import nltk
# NOT NEEDED import json
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../raw/Onboard_Survey.csv")

df.head()
# Out:
#                       Timestamp What is your age group?  \
# 0   2021/06/11 7:04:48 AM GMT+7             25-34 years
# 1  2021/06/11 11:55:36 AM GMT+7             55-70 years
# 2   2021/06/11 7:11:53 PM GMT+7             35-44 years
# 3   2021/06/11 8:26:19 PM GMT+7             35-44 years
# 4  2021/06/11 10:42:08 PM GMT+7             25-34 years
#
#   What country do you reside in?  \
# 0       United States of America
# 1                          India
# 2       United States of America
# 3                      Singapore
# 4       United States of America
#
#   What is your discord handle? (Must provide this to be entered into raffle)  \
# 0                                            @redvan
# 1                                          Analytics
# 2                                            themuss
# 3                                       @angyts#1036
# 4                                      rozayyyy#4729
#
#   When did you first acquire a crypto currency (bitcoin, ethereum, etc.)?  \
# 0                                      3-5 years ago
# 1                               Within the last year
# 2                                      3-5 years ago
# 3                                      1-2 years ago
# 4                                5 or more years ago
#
#   What wallet(s) are you using now? Check as many as applicable. Check none if you don't have one.  \
# 0                           Metamask;Coinbase;trezor
# 1                                        Trustwallet
# 2                           Metamask;Argent;Coinbase
# 3                                    Metamask;trezor
# 4  Metamask;Trustwallet;Ledger;Argent;Coinbase;De...
#
#   If you have used a wallet, what was your first wallet and why did you choose that one?  \
# 0                      Trezor - needed cold storage.
# 1                Trustwallet, was not knowing much,
# 2                     Coinbase, ease of transactions
# 3               trezor, it just works and its secure
# 4                   Coinbase bc it was a whileee ago
#
#   What has been painful about using wallets or what has been or is an obstacle in your way to using a wallet?  \
# 0        keeping up with all the security parameters
# 1  still not coming to terms, which wallet to use...
# 2                                                NaN
# 3  setting up is painful, and dealing with the se...
# 4                          Feees, centralization etc
#
#   When did you first use a DeFi app (AAVE, Uniswap, etc.)?  \
# 0                               Within the last year
# 1                             I have never used DeFi
# 2                               Within the last year
# 3                               Within the last year
# 4                                      3-5 years ago
#
#   If you have used a DeFi app, what was your first app and why did you choose that one?  \
# 0      uniswap - seems to have a stellar reputation.
# 1                                                NaN
# 2                                                NaN
# 3             Uniswap, i had to trade between assets
# 4                                                NaN
#
#   What has been painful about using DeFi apps or what has or is an obstacle in your way to using a DeFi app?  \
# 0            Learning how to navigate web3 websites.
# 1                                                NaN
# 2                                                NaN
# 3               Gas fees are fluctuating each second
# 4                                                NaN
#
#   Tell us about one positive or unexpected outcome you had from using a DeFi app?  \
# 0  Discovered new financial products and revenue ...
# 1                                                NaN
# 2                                                NaN
# 3                    lost money from weird protocols
# 4                                                NaN
#
#   What DeFi app are you most interested in using?  \
# 0                                        Alchemix
# 1                                             NaN
# 2                                            AAVE
# 3                                         Options
# 4                                             NaN
#
#                           What is your DeFi endgame?
# 0                        Passive income through DeFi
# 1                                                NaN
# 2               Move my traditional investments over
# 3  Become a DeFi native and have more DeFi assets...
# 4                                                NaN

# %%
# skip first seven columns df.iloc[:, 0:7].head()

# selecting only open-ended responses 
df.iloc[:, 6:14].head()

open_ended = df.iloc[:, 6:14]

open_ended.head()
# Out:
#   If you have used a wallet, what was your first wallet and why did you choose that one?  \
# 0                      Trezor - needed cold storage.
# 1                Trustwallet, was not knowing much,
# 2                     Coinbase, ease of transactions
# 3               trezor, it just works and its secure
# 4                   Coinbase bc it was a whileee ago
#
#   What has been painful about using wallets or what has been or is an obstacle in your way to using a wallet?  \
# 0        keeping up with all the security parameters
# 1  still not coming to terms, which wallet to use...
# 2                                                NaN
# 3  setting up is painful, and dealing with the se...
# 4                          Feees, centralization etc
#
#   When did you first use a DeFi app (AAVE, Uniswap, etc.)?  \
# 0                               Within the last year
# 1                             I have never used DeFi
# 2                               Within the last year
# 3                               Within the last year
# 4                                      3-5 years ago
#
#   If you have used a DeFi app, what was your first app and why did you choose that one?  \
# 0      uniswap - seems to have a stellar reputation.
# 1                                                NaN
# 2                                                NaN
# 3             Uniswap, i had to trade between assets
# 4                                                NaN
#
#   What has been painful about using DeFi apps or what has or is an obstacle in your way to using a DeFi app?  \
# 0            Learning how to navigate web3 websites.
# 1                                                NaN
# 2                                                NaN
# 3               Gas fees are fluctuating each second
# 4                                                NaN
#
#   Tell us about one positive or unexpected outcome you had from using a DeFi app?  \
# 0  Discovered new financial products and revenue ...
# 1                                                NaN
# 2                                                NaN
# 3                    lost money from weird protocols
# 4                                                NaN
#
#   What DeFi app are you most interested in using?  \
# 0                                        Alchemix
# 1                                             NaN
# 2                                            AAVE
# 3                                         Options
# 4                                             NaN
#
#                           What is your DeFi endgame?
# 0                        Passive income through DeFi
# 1                                                NaN
# 2               Move my traditional investments over
# 3  Become a DeFi native and have more DeFi assets...
# 4                                                NaN

# %%
# Column: If you have used a wallet, what was your first wallet and why did you choose that one?

empty_list = []

 # store strings from each row in an empty list
for row in open_ended.iloc[:,0]:
    empty_list.append(row)

empty_list2 = []

# store first word from each string into empty_list2
# try-except to handle exception
# n = 180
for string in empty_list:
    try: 
        empty_list2.append(string.split()[0])
    except:
        continue

# %%
# see how many strings out of 180 is stored
# we got 176
# NOTE: most people respond directly, but some answer in sentences

len(empty_list2)
# Out:
# 176

# %%
empty_list3 = []

# convert all words to lowercase and remove non-alphanumeric characters
for word in empty_list2:
    s = re.sub(r'\W+', '', word.lower())
    empty_list3.append(s)
    
pd.Series(empty_list3).value_counts()
# Out:
# metamask                    69
# coinbase                    29
# ledger                      19
# i                            5
# myetherwallet                5
# trezor                       5
# trustwallet                  4
# my                           3
# exodus                       3
# trust                        3
# blockchain                   3
# electrum                     3
# httpswwwmyetherwalletcom     2
# coinomi                      2
# mew                          2
# coinspot                     1
# bitcoin                      1
# argent                       1
# lattice                      1
# greenwallet                  1
# the                          1
# portismetamask               1
# excudus                      1
# first                        1
# free                         1
# opened                       1
# kraken                       1
# lots                         1
# tron                         1
# freebitco                    1
# mycelium                     1
# coinbasei                    1
# originally                   1
# atomic                       1
# dtype: int64

# %%
# split string, everything EXCEPT first word

empty_list2a = []

for string in empty_list:
    try:
        other = string.split()[1:]
    except:
        continue
    empty_list2a.append(' '.join(other))
    
empty_list2a
# Out:
# ['- needed cold storage.',
#  'was not knowing much,',
#  'ease of transactions',
#  'it just works and its secure',
#  'bc it was a whileee ago',
#  'Wallet',
#  "It's easy to get started",
#  '',
#  'Felt that a cold-storage, hardware wallet was most secure.',
#  'as it was a hardware wallet',
#  '- Bankless podcast',
#  'and then a Ledger 3 weeks later. I chose these based on recommendations from my friend who got me started.',
#  'first was Coinbase Wallet because Coinbase was my first exchange. I no longer use it, in favor of MetaMask.',
#  'easy to use and trusted exchange',
#  'Was the easiest to use in 2017.',
#  '- fiat onboarding',
#  'Easy full-featured desktop/web wallet',
#  'tbh, when Mark Cuban said he uses Metamask, that when I installed it. This was when I first was getting started. I use multiple wallets, including other blockchains (ie Cosmostation, Keplr)',
#  'Most recommended',
#  'recommended by Bankless',
#  'easy to setup and compatible with a lot of apps',
#  '',
#  '- it was the most recommended and seemed to be the most comprehensive (less siloed)',
#  'because I heard about it on Bankless.',
#  '- in order to acquire Gods Unchained cards',
#  '',
#  'seemed like a popular choice.',
#  '- most Ethereum friendly',
#  'Wallet, it was recommended as part of the onboarding for a coin I wanted',
#  'first one I used was Argent. It was recommended (or was it a sponsor?) on Bankless. I absolutely needed a wallet because I wanted to buy Realtokens (tokenized real estate). It felt very easy to use, secure, and transactions were paid for at the time. Looked like another banking app so it was very reassuring, plus no need to use seed phrase.',
#  'to buy DPI',
#  'used it because it was the first one I heard about.',
#  'one of the best wallet for bitcoin storage in my opinion',
#  'think there was only 1 bitcoin wallet in 2013.',
#  'for self custody and private key management',
#  'Friend walked me through buying BTC',
#  'First one that I came across.',
#  'Wallet',
#  "because it's the wallet you can use everything with and it still is.",
#  'because it was easy. Quickly moved to Metamask and added Ledger redundancy soon thereafter.',
#  'was my first noncustodial wallet. ease of use. Metamask later became my first custodial wallet for the same reasons.',
#  "it's the first wallet most use due to onboarding. Trustwallet was my second. It was super easy.",
#  '(was there any other at the time)',
#  'because widely recommended and developed by Consensys',
#  'Trust. Ease.',
#  '',
#  'most easily integrated with defi apps',
#  'because you guys recommended it',
#  '',
#  'for ease of use',
#  'for smart contract development',
#  'most widely used',
#  'nano s. Friend recommended',
#  '- used with a friend who was showing me how to use crypto',
#  '- it was the most popular at the time (2017/2018)',
#  'Friend recommended',
#  'My friends recommended it and it seemed like the wallet with the best compatibility.',
#  'because i love eth',
#  'chose Ledger for security purposes and because it was the most recommended.',
#  ', most convenient and easiest to use.',
#  'Just what I was turned onto first.',
#  'It was (and is) the industry standard.',
#  '- first available!',
#  '- back in the early days of ETH, that was pretty much the only one',
#  "was my first wallet in 2013 didn't know any other at the time. After that I had a huge break from crypto then got into metamask and crypto.com",
#  'then Metamask, then Ledger. Increased security along the way as my portfolio (and associated risks) grew!',
#  'for security',
#  '- thought it was the most secure until the hack, lost my trust',
#  'to store ETH',
#  'ease of browser integration and anonymous. Ledger due to small form factor.',
#  'It was simple to learn and it was secure. It had awesome design also.',
#  ', I could put it in my browser',
#  'cuz I was dumb and Reddit said it was ok',
#  '- seemed like a decently rated wallet from different review sites',
#  'I was told, not your coins, not your keys, and that seemed like a great option',
#  'cousin told me to',
#  'Web3 accessibility',
#  'it was a setup for a gift of doge',
#  '- easiest access. Recommended by a friend',
#  'of goggling good wallets,',
#  "because everyone's using it and it was the first recommendation",
#  '-- seemed the best choice at the time',
#  'it was easy to access.',
#  'because it was easy to use with my Coinbase account.',
#  "because it's easy and convenient.",
#  'had a great interface and the possibilities to show collected NFTs',
#  "Ether Wallet, seemed like a good option at the time. Doesn't integrate as easily with a lot of DeFi apps though.",
#  'because it was easy',
#  'reputation',
#  'and I forget why but probably because it was the one the dApp suggested I connect to',
#  'Ease',
#  'Chose it because I read about it online while trying out Cryptokitties',
#  'wallet',
#  'Because it is a Decentralized Wallet',
#  'Seemed easy to use, looked familiar somehow (maybe Firefox). Most people seemed to recommend it.',
#  'because I felt safe with it.',
#  '',
#  'Non-custodial.',
#  '',
#  'I tried loads, bread and Jaxx but blockchain was the first transaction and it worked.',
#  'as was my first exchange',
#  'Found thru web tutorial',
#  "- through advice on a Youtube Channel (I don't personally know anyone into Crypto and Defi)",
#  'wallet was the first time I ever used a wallet. As my first CEX I naturally trusted their wallet initially above all others. Very quickly moved to MetaMask after doing some research.',
#  'Bankless guys promoted it.',
#  'first one available',
#  'because it was the industry standard and seemed to have the best integrations with dApps from what I read at the time',
#  "Can't remember what the particular reason was. I think it was the only serious one at that time.",
#  'Most popular one',
#  'security',
#  'used Celsius and coinbase before transferring to a Ledger connected to Metamask. I picked this because of good security.',
#  "I didn't know metamask or hardware wallet when I first engaged with crypto. Also Coinbase was my first gate to convert fiat to crypto.",
#  "because I wanted a hardware wallet and my cousin had a ledger and didn't like it so I tried the other most popular hardware.",
#  'Well known & easy to use.',
#  'Easy to use.',
#  'Security.',
#  'easy to connect my bank and trusted not to lose my money',
#  'It was pitched as the safest and most convenient.',
#  'was MetaMask because its in all the tutorials. Next was Ledger to have a cold wallet.',
#  '',
#  'recommended by Bankless',
#  'free app',
#  'security',
#  '',
#  '',
#  '',
#  '',
#  'OSS project , i can run locally and it is safe as the source code is open',
#  '- reason, DeFi',
#  'because it was deemed the safest',
#  'researched on www',
#  'core, it was the only thing at the time, the next wallets I used were litecoin core and then electrum',
#  "for sure as it's really convenient: you can use it on every Dapp and every EVM compatible chains.",
#  'chose the Ledger Wallet for security.',
#  'Apart from interacting with Coinbase first. It was the first one I came around, and someone provided me with a guide on how to use it, what is a private key, public key, and seed phrase. Once I understood Metamask and Argent, I was sold. These were much more user-friendly.',
#  'following recommandations.',
#  'seemed to have best combination of security and good usability',
#  'great UX',
#  '',
#  'to get airdrops',
#  'was the first so that I could acquire eth.',
#  '',
#  'A friend of mine recommended it.',
#  'biggest name and most used',
#  'because it was recommended to me by a Youtuber I follow for about 4 years',
#  '- following online tutorials',
#  'I chose it after doing some research, it was the most reliable',
#  "don't remember what my first wallet was, but metamask has been my default for years, with trust as a secondary that could support non eth assets",
#  '- path of least resistance when I was first starting out.',
#  'easy onramp',
#  'the kraken wallet in 2012 with $25. Wanted to buy 10K worth of btc but my husband convinced me that it would be a bad idea. We put it in some shit cannabis stock instead and promptly lost it all. He is still calculating what our $10K would be worth today.',
#  'for convenience and security, then linked with ledger',
#  '',
#  'hodl on coinbase exchange. Then discovered MetaMask and DeFi.',
#  '- easy to install as an extension',
#  'wallet because it was the first ecosystem that I used.',
#  'most public known',
#  'It was associated to an airdrop and I had to open and used it to get the airdrop.',
#  'it was easiest to convert fiat',
#  'because it was a popular community recommendation at the time.',
#  'security',
#  '- easy investing',
#  'Wallet had multi coin capability',
#  '- ease of use in getting onboarded back in 2015',
#  "- because it's like Visa. It's everywhere you wanna be.",
#  "app, because it's the first thing I found, years ago.",
#  'It was connected to my mining rigs.',
#  'because I like that it was a chrome extension',
#  'because it was for a browser extension. then trust for mobile first.',
#  'because I wanted a simple hardware wallet and it was the most popular at the time.',
#  '- Chose it because other people recommended it',
#  'was told it was the easiest most secure. After my research I agreed.',
#  'original wallet was a Ledger Nano S. I picked that one based on a recommendation from a friend',
#  '',
#  '- came with Brave',
#  ', Bankless Advertisement']

# %%
len(empty_list2a)
# Out:
# 176

# %%
# rename columns
open_ended.columns = ['walletwhat_walletwhy', 'wallet_pain', 'defi_when', 'defiwhat_defiwhy', 'defi_pain', 'defi_outcome', 'defi_interest', 'defi_endgame']


open_ended.head()
# Out:
#                    walletwhat_walletwhy  \
# 0         Trezor - needed cold storage.
# 1   Trustwallet, was not knowing much,
# 2        Coinbase, ease of transactions
# 3  trezor, it just works and its secure
# 4      Coinbase bc it was a whileee ago
#
#                                          wallet_pain               defi_when  \
# 0        keeping up with all the security parameters    Within the last year
# 1  still not coming to terms, which wallet to use...  I have never used DeFi
# 2                                                NaN    Within the last year
# 3  setting up is painful, and dealing with the se...    Within the last year
# 4                          Feees, centralization etc           3-5 years ago
#
#                                 defiwhat_defiwhy  \
# 0  uniswap - seems to have a stellar reputation.
# 1                                            NaN
# 2                                            NaN
# 3         Uniswap, i had to trade between assets
# 4                                            NaN
#
#                                  defi_pain  \
# 0  Learning how to navigate web3 websites.
# 1                                      NaN
# 2                                      NaN
# 3     Gas fees are fluctuating each second
# 4                                      NaN
#
#                                         defi_outcome defi_interest  \
# 0  Discovered new financial products and revenue ...      Alchemix
# 1                                                NaN           NaN
# 2                                                NaN          AAVE
# 3                    lost money from weird protocols       Options
# 4                                                NaN           NaN
#
#                                         defi_endgame
# 0                        Passive income through DeFi
# 1                                                NaN
# 2               Move my traditional investments over
# 3  Become a DeFi native and have more DeFi assets...
# 4                                                NaN

# %%
open_ended["walletwhat"] = open_ended["walletwhat_walletwhy"].str.split(' ').str[0]

open_ended.head()
# Out:
# <ipython-input-82-b884014e5d2a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   open_ended["walletwhat"] = open_ended["walletwhat_walletwhy"].str.split(' ').str[0]
#                    walletwhat_walletwhy  \
# 0         Trezor - needed cold storage.
# 1   Trustwallet, was not knowing much,
# 2        Coinbase, ease of transactions
# 3  trezor, it just works and its secure
# 4      Coinbase bc it was a whileee ago
#
#                                          wallet_pain               defi_when  \
# 0        keeping up with all the security parameters    Within the last year
# 1  still not coming to terms, which wallet to use...  I have never used DeFi
# 2                                                NaN    Within the last year
# 3  setting up is painful, and dealing with the se...    Within the last year
# 4                          Feees, centralization etc           3-5 years ago
#
#                                 defiwhat_defiwhy  \
# 0  uniswap - seems to have a stellar reputation.
# 1                                            NaN
# 2                                            NaN
# 3         Uniswap, i had to trade between assets
# 4                                            NaN
#
#                                  defi_pain  \
# 0  Learning how to navigate web3 websites.
# 1                                      NaN
# 2                                      NaN
# 3     Gas fees are fluctuating each second
# 4                                      NaN
#
#                                         defi_outcome defi_interest  \
# 0  Discovered new financial products and revenue ...      Alchemix
# 1                                                NaN           NaN
# 2                                                NaN          AAVE
# 3                    lost money from weird protocols       Options
# 4                                                NaN           NaN
#
#                                         defi_endgame    walletwhat  defiwhat
# 0                        Passive income through DeFi        Trezor   uniswap
# 1                                                NaN  Trustwallet,       NaN
# 2               Move my traditional investments over     Coinbase,       NaN
# 3  Become a DeFi native and have more DeFi assets...       trezor,  uniswap,
# 4                                                NaN      Coinbase       NaN

# %%
open_ended["walletwhat"] = open_ended["walletwhat"].str.lower()

open_ended.head()
# Out:
# <ipython-input-83-0617123e2690>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   open_ended["walletwhat"] = open_ended["walletwhat"].str.lower()
#                    walletwhat_walletwhy  \
# 0         Trezor - needed cold storage.
# 1   Trustwallet, was not knowing much,
# 2        Coinbase, ease of transactions
# 3  trezor, it just works and its secure
# 4      Coinbase bc it was a whileee ago
#
#                                          wallet_pain               defi_when  \
# 0        keeping up with all the security parameters    Within the last year
# 1  still not coming to terms, which wallet to use...  I have never used DeFi
# 2                                                NaN    Within the last year
# 3  setting up is painful, and dealing with the se...    Within the last year
# 4                          Feees, centralization etc           3-5 years ago
#
#                                 defiwhat_defiwhy  \
# 0  uniswap - seems to have a stellar reputation.
# 1                                            NaN
# 2                                            NaN
# 3         Uniswap, i had to trade between assets
# 4                                            NaN
#
#                                  defi_pain  \
# 0  Learning how to navigate web3 websites.
# 1                                      NaN
# 2                                      NaN
# 3     Gas fees are fluctuating each second
# 4                                      NaN
#
#                                         defi_outcome defi_interest  \
# 0  Discovered new financial products and revenue ...      Alchemix
# 1                                                NaN           NaN
# 2                                                NaN          AAVE
# 3                    lost money from weird protocols       Options
# 4                                                NaN           NaN
#
#                                         defi_endgame    walletwhat  defiwhat
# 0                        Passive income through DeFi        trezor   uniswap
# 1                                                NaN  trustwallet,       NaN
# 2               Move my traditional investments over     coinbase,       NaN
# 3  Become a DeFi native and have more DeFi assets...       trezor,  uniswap,
# 4                                                NaN      coinbase       NaN

# %%
open_ended['defiwhat'] = open_ended["defiwhat_defiwhy"].str.split(' ').str[0]

open_ended.head()
# Out:
# <ipython-input-84-c2130ddb1519>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   open_ended['defiwhat'] = open_ended["defiwhat_defiwhy"].str.split(' ').str[0]
#                    walletwhat_walletwhy  \
# 0         Trezor - needed cold storage.
# 1   Trustwallet, was not knowing much,
# 2        Coinbase, ease of transactions
# 3  trezor, it just works and its secure
# 4      Coinbase bc it was a whileee ago
#
#                                          wallet_pain               defi_when  \
# 0        keeping up with all the security parameters    Within the last year
# 1  still not coming to terms, which wallet to use...  I have never used DeFi
# 2                                                NaN    Within the last year
# 3  setting up is painful, and dealing with the se...    Within the last year
# 4                          Feees, centralization etc           3-5 years ago
#
#                                 defiwhat_defiwhy  \
# 0  uniswap - seems to have a stellar reputation.
# 1                                            NaN
# 2                                            NaN
# 3         Uniswap, i had to trade between assets
# 4                                            NaN
#
#                                  defi_pain  \
# 0  Learning how to navigate web3 websites.
# 1                                      NaN
# 2                                      NaN
# 3     Gas fees are fluctuating each second
# 4                                      NaN
#
#                                         defi_outcome defi_interest  \
# 0  Discovered new financial products and revenue ...      Alchemix
# 1                                                NaN           NaN
# 2                                                NaN          AAVE
# 3                    lost money from weird protocols       Options
# 4                                                NaN           NaN
#
#                                         defi_endgame    walletwhat  defiwhat
# 0                        Passive income through DeFi        trezor   uniswap
# 1                                                NaN  trustwallet,       NaN
# 2               Move my traditional investments over     coinbase,       NaN
# 3  Become a DeFi native and have more DeFi assets...       trezor,  Uniswap,
# 4                                                NaN      coinbase       NaN

# %%
open_ended['defiwhat'] = open_ended['defiwhat'].str.lower()

open_ended.head()
# Out:
# <ipython-input-85-e6ab9d6029c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   open_ended['defiwhat'] = open_ended['defiwhat'].str.lower()
#                    walletwhat_walletwhy  \
# 0         Trezor - needed cold storage.
# 1   Trustwallet, was not knowing much,
# 2        Coinbase, ease of transactions
# 3  trezor, it just works and its secure
# 4      Coinbase bc it was a whileee ago
#
#                                          wallet_pain               defi_when  \
# 0        keeping up with all the security parameters    Within the last year
# 1  still not coming to terms, which wallet to use...  I have never used DeFi
# 2                                                NaN    Within the last year
# 3  setting up is painful, and dealing with the se...    Within the last year
# 4                          Feees, centralization etc           3-5 years ago
#
#                                 defiwhat_defiwhy  \
# 0  uniswap - seems to have a stellar reputation.
# 1                                            NaN
# 2                                            NaN
# 3         Uniswap, i had to trade between assets
# 4                                            NaN
#
#                                  defi_pain  \
# 0  Learning how to navigate web3 websites.
# 1                                      NaN
# 2                                      NaN
# 3     Gas fees are fluctuating each second
# 4                                      NaN
#
#                                         defi_outcome defi_interest  \
# 0  Discovered new financial products and revenue ...      Alchemix
# 1                                                NaN           NaN
# 2                                                NaN          AAVE
# 3                    lost money from weird protocols       Options
# 4                                                NaN           NaN
#
#                                         defi_endgame    walletwhat  defiwhat
# 0                        Passive income through DeFi        trezor   uniswap
# 1                                                NaN  trustwallet,       NaN
# 2               Move my traditional investments over     coinbase,       NaN
# 3  Become a DeFi native and have more DeFi assets...       trezor,  uniswap,
# 4                                                NaN      coinbase       NaN

# %%
# first rename columns to make them manageable
# now that we've split 'wallet' and 'defi' into 'what' and 'why'
# we can clean the 'what' and tally
# we can filter by popular 'what' and quickly get a sense for the 'why' 
# **Filter by words should yield most impact in minimal time

# process the data: 
# (advanced w/ more time: we can apply topic modeling or LDA to the 'why')

# %%
# clean walletwhat and defiwhat column(s) by removing non-alphanumeric characters

open_ended['walletwhat'] = open_ended['walletwhat'].str.replace('[^a-zA-Z0-9]', '')
open_ended['defiwhat'] = open_ended['defiwhat'].str.replace('[^a-zA-Z0-9]', '')

open_ended.head()
# Out:
# <ipython-input-113-4c3a31b501ae>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   open_ended['walletwhat'] = open_ended['walletwhat'].str.replace('[^a-zA-Z0-9]', '')
# <ipython-input-113-4c3a31b501ae>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   open_ended['defiwhat'] = open_ended['defiwhat'].str.replace('[^a-zA-Z0-9]', '')
#                    walletwhat_walletwhy  \
# 0         Trezor - needed cold storage.
# 1   Trustwallet, was not knowing much,
# 2        Coinbase, ease of transactions
# 3  trezor, it just works and its secure
# 4      Coinbase bc it was a whileee ago
#
#                                          wallet_pain               defi_when  \
# 0        keeping up with all the security parameters    Within the last year
# 1  still not coming to terms, which wallet to use...  I have never used DeFi
# 2                                                NaN    Within the last year
# 3  setting up is painful, and dealing with the se...    Within the last year
# 4                          Feees, centralization etc           3-5 years ago
#
#                                 defiwhat_defiwhy  \
# 0  uniswap - seems to have a stellar reputation.
# 1                                            NaN
# 2                                            NaN
# 3         Uniswap, i had to trade between assets
# 4                                            NaN
#
#                                  defi_pain  \
# 0  Learning how to navigate web3 websites.
# 1                                      NaN
# 2                                      NaN
# 3     Gas fees are fluctuating each second
# 4                                      NaN
#
#                                         defi_outcome defi_interest  \
# 0  Discovered new financial products and revenue ...      Alchemix
# 1                                                NaN           NaN
# 2                                                NaN          AAVE
# 3                    lost money from weird protocols       Options
# 4                                                NaN           NaN
#
#                                         defi_endgame   walletwhat defiwhat
# 0                        Passive income through DeFi       trezor  uniswap
# 1                                                NaN  trustwallet      NaN
# 2               Move my traditional investments over     coinbase      NaN
# 3  Become a DeFi native and have more DeFi assets...       trezor  uniswap
# 4                                                NaN     coinbase      NaN

# %%
# tally words in walletwhat and defiwhat column(s)

open_ended['walletwhat'].value_counts()
# Out:
# metamask                    69
# coinbase                    29
# ledger                      19
# i                            5
# myetherwallet                5
# trezor                       5
# trustwallet                  4
# my                           3
# exodus                       3
# trust                        3
# blockchain                   3
# electrum                     3
# httpswwwmyetherwalletcom     2
# coinomi                      2
# mew                          2
# coinspot                     1
# bitcoin                      1
# argent                       1
# lattice                      1
# greenwallet                  1
# the                          1
# portismetamask               1
# excudus                      1
# first                        1
# free                         1
# opened                       1
# kraken                       1
# lots                         1
# tron                         1
# freebitco                    1
# mycelium                     1
# coinbasei                    1
# originally                   1
# atomic                       1
# Name: walletwhat, dtype: int64

# %%
# tally words in walletwhat and defiwhat column(s)

open_ended['defiwhat'].value_counts()
# Out:
# uniswap     54
# compound    15
# aave        10
# i            6
# maker        6
#             ..
# beefy        1
# pickle       1
# ens          1
# not          1
# raydium      1
# Name: defiwhat, Length: 61, dtype: int64
